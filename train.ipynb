# %%
import os
import glob
import numpy as np
from sklearn.model_selection import StratifiedKFold
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from loader import FeatureLoader
from model import AttentionMIL

# %%
def phase_step(model, dataloader, optimizer, criterion, phase, device):

    if phase == 'train':
        train=True
        model.train()

    if phase == 'valid':
        train=False
        model.eval()

    with torch.set_grad_enabled(train):

        phase_loss, phase_metr = 0.0, 0.0

        for data in dataloader:

            X = data['X'].to(device)
            Y = data['Y'].to(device)

            # Forward pass
            optimizer.zero_grad()
            P, A = model(X)
            loss = criterion(P, Y.long())

            # Backward Pass
            if train:
                loss.backward()
                optimizer.step()

            with torch.no_grad():
                P = torch.argmax(P, dim=-1)
                metr = P.eq(Y).sum()

            phase_loss += loss.item()
            phase_metr += metr.item()

        phase_loss = phase_loss/len(dataloader)
        phase_metr = phase_metr/len(dataloader)

    return phase_loss, phase_metr

# %%
def main(config):

    
    print(f'\nFold-{config["fold"]} ...', flush=True)

    
    # Arange files and labels
    
    files = sorted(glob.glob(f'{config["data_dir"]}/*.h5'))
    labels = np.array([int(f.split('/')[-1][5]) for f in files]) - 1

    
    # K-Fold Split
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
    
    train_indices, valid_indices = list(skf.split(files, labels))[config["fold"]]
        
    train_samples = [{"X": files[i], "Y":labels[i]} for i in train_indices]
    valid_samples = [{"X": files[i], "Y":labels[i]} for i in valid_indices]
    
    np.random.shuffle(train_samples)
    
    print(f'\nNumber of train files: {len(train_samples)}', flush=True)
    print(f'Number of valid_files: {len(valid_samples)}', flush=True)

    
    # Create dataset
    
    train_ds = FeatureLoader(train_samples)
    valid_ds = FeatureLoader(valid_samples)
    
    train_ds = DataLoader(train_ds, batch_size=None, shuffle=True, pin_memory=True)
    valid_ds = DataLoader(valid_ds, batch_size=None, shuffle=False, pin_memory=True)

    
    # Set device
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f'\nDevice: {device}')

    
    # Create model
    model = AttentionMIL(feature_size=1024, classes=3).to(device)
    print(f'\nModel compiled', flush=True)

    
    # Weights
    
    weights = np.array([96, 96, 48])
    weights = 1 / weights * np.sum(weights) / 3
    weights = torch.tensor(weights).float().to(device)
    
    
    # Loss, optimizer and scheduler
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), 1e-3)
    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=5, verbose=False)
    
    checkpoint_path = f'{config["save_dir"]}/model_f{config["fold"]}.pt'

    
    # Training
    
    print(f'\nTraining ...')

    monitor_metr = 0
    
    for epoch in range(0, config["epochs"]):

        print(f'\nEpoch {epoch:03}/{config["epochs"]:03}')

        for phase in ['train', 'valid']:
            
            dataloader = train_ds if phase == 'train' else valid_ds
            
            phase_loss, phase_metr = phase_step(model, dataloader, optimizer, criterion, phase, device)
            print(f'{phase}_loss: {phase_loss:0.4f} - {phase}_accuracy: {phase_metr:0.4f}')

        if phase_metr>monitor_metr:
            
            state = {'epoch': epoch,
                     'state_dict': model.state_dict(),
                     'optimizer': optimizer.state_dict()}
            
            torch.save(state, checkpoint_path)
            print(f'checkpoint saved: {checkpoint_path}')
            
            monitor_metr = phase_metr
            
        scheduler.step(phase_metr)
        

    print(f'\nComplete! Validation Accuracy = {monitor_metr}')

# %%
if __name__ == "__main__":
        
    for fold in range(5):

        config = {
            "data_dir": '/mnt/scratch/crc/data/features/features_0512',
            "save_dir": '/mnt/scratch/crc/models/models_0512',
            "epochs": 25,
            "fold": fold,
            "seed": 0,
        }

        if not os.path.exists(config["save_dir"]):
            os.makedirs(config["save_dir"])
            
        main(config)
        
        print('\n\n')
# Out:
# Fold-0 ...
#
# Number of train files: 240
# Number of valid_files: 60
#
# Device: cuda
#
# Model compiled
#
# Training ...
#
# Epoch 000/025
# train_loss: 0.9069 - train_accuracy: 0.6417
# valid_loss: 0.4044 - valid_accuracy: 0.8333
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f0.pt
#
# Epoch 001/025
# train_loss: 0.3491 - train_accuracy: 0.8667
# valid_loss: 0.5030 - valid_accuracy: 0.8333
#
# Epoch 002/025
# train_loss: 0.1553 - train_accuracy: 0.9458
# valid_loss: 0.4328 - valid_accuracy: 0.7667
#
# Epoch 003/025
# train_loss: 0.1565 - train_accuracy: 0.9458
# valid_loss: 0.0948 - valid_accuracy: 0.9500
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f0.pt
#
# Epoch 004/025
# train_loss: 0.1209 - train_accuracy: 0.9583
# valid_loss: 0.1029 - valid_accuracy: 0.9500
#
# Epoch 005/025
# train_loss: 0.0524 - train_accuracy: 0.9875
# valid_loss: 0.0355 - valid_accuracy: 1.0000
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f0.pt
#
# Epoch 006/025
# train_loss: 0.1581 - train_accuracy: 0.9542
# valid_loss: 0.0724 - valid_accuracy: 0.9667
#
# Epoch 007/025
# train_loss: 0.1831 - train_accuracy: 0.9542
# valid_loss: 0.0708 - valid_accuracy: 0.9833
#
# Epoch 008/025
# train_loss: 0.0720 - train_accuracy: 0.9750
# valid_loss: 0.0617 - valid_accuracy: 0.9667
#
# Epoch 009/025
# train_loss: 0.1212 - train_accuracy: 0.9542
# valid_loss: 0.2259 - valid_accuracy: 0.9333
#
# Epoch 010/025
# train_loss: 0.1670 - train_accuracy: 0.9375
# valid_loss: 0.0567 - valid_accuracy: 0.9667
#
# Epoch 011/025
# train_loss: 0.0364 - train_accuracy: 0.9792
# valid_loss: 0.1468 - valid_accuracy: 0.9500
#
# Epoch 012/025
# train_loss: 0.0247 - train_accuracy: 0.9958
# valid_loss: 0.0414 - valid_accuracy: 0.9833
#
# Epoch 013/025
# train_loss: 0.0089 - train_accuracy: 1.0000
# valid_loss: 0.0496 - valid_accuracy: 0.9833
#
# Epoch 014/025
# train_loss: 0.0073 - train_accuracy: 1.0000
# valid_loss: 0.0528 - valid_accuracy: 0.9833
#
# Epoch 015/025
# train_loss: 0.0062 - train_accuracy: 1.0000
# valid_loss: 0.0500 - valid_accuracy: 0.9833
#
# Epoch 016/025
# train_loss: 0.0052 - train_accuracy: 1.0000
# valid_loss: 0.0552 - valid_accuracy: 0.9833
#
# Epoch 017/025
# train_loss: 0.0044 - train_accuracy: 1.0000
# valid_loss: 0.0504 - valid_accuracy: 0.9833
#
# Epoch 018/025
# train_loss: 0.0039 - train_accuracy: 1.0000
# valid_loss: 0.0500 - valid_accuracy: 0.9833
#
# Epoch 019/025
# train_loss: 0.0038 - train_accuracy: 1.0000
# valid_loss: 0.0501 - valid_accuracy: 0.9833
#
# Epoch 020/025
# train_loss: 0.0037 - train_accuracy: 1.0000
# valid_loss: 0.0501 - valid_accuracy: 0.9833
#
# Epoch 021/025
# train_loss: 0.0039 - train_accuracy: 1.0000
# valid_loss: 0.0501 - valid_accuracy: 0.9833
#
# Epoch 022/025
# train_loss: 0.0038 - train_accuracy: 1.0000
# valid_loss: 0.0495 - valid_accuracy: 0.9833
#
# Epoch 023/025
# train_loss: 0.0035 - train_accuracy: 1.0000
# valid_loss: 0.0494 - valid_accuracy: 0.9833
#
# Epoch 024/025
# train_loss: 0.0034 - train_accuracy: 1.0000
# valid_loss: 0.0493 - valid_accuracy: 0.9833
#
# Complete! Validation Accuracy = 1.0
#
#
#
#
# Fold-1 ...
#
# Number of train files: 240
# Number of valid_files: 60
#
# Device: cuda
#
# Model compiled
#
# Training ...
#
# Epoch 000/025
# train_loss: 0.5304 - train_accuracy: 0.8042
# valid_loss: 0.3516 - valid_accuracy: 0.8333
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f1.pt
#
# Epoch 001/025
# train_loss: 0.2240 - train_accuracy: 0.9083
# valid_loss: 0.2281 - valid_accuracy: 0.9667
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f1.pt
#
# Epoch 002/025
# train_loss: 0.1349 - train_accuracy: 0.9500
# valid_loss: 0.4132 - valid_accuracy: 0.9167
#
# Epoch 003/025
# train_loss: 0.1145 - train_accuracy: 0.9542
# valid_loss: 0.0562 - valid_accuracy: 0.9833
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f1.pt
#
# Epoch 004/025
# train_loss: 0.0887 - train_accuracy: 0.9708
# valid_loss: 0.1957 - valid_accuracy: 0.9167
#
# Epoch 005/025
# train_loss: 0.0915 - train_accuracy: 0.9708
# valid_loss: 0.1839 - valid_accuracy: 0.9500
#
# Epoch 006/025
# train_loss: 0.1474 - train_accuracy: 0.9500
# valid_loss: 0.1410 - valid_accuracy: 0.9167
#
# Epoch 007/025
# train_loss: 0.1072 - train_accuracy: 0.9667
# valid_loss: 0.3286 - valid_accuracy: 0.9167
#
# Epoch 008/025
# train_loss: 0.0947 - train_accuracy: 0.9625
# valid_loss: 0.7507 - valid_accuracy: 0.7667
#
# Epoch 009/025
# train_loss: 0.0553 - train_accuracy: 0.9792
# valid_loss: 0.1709 - valid_accuracy: 0.9500
#
# Epoch 010/025
# train_loss: 0.0170 - train_accuracy: 0.9917
# valid_loss: 0.1591 - valid_accuracy: 0.9500
#
# Epoch 011/025
# train_loss: 0.0133 - train_accuracy: 0.9958
# valid_loss: 0.1519 - valid_accuracy: 0.9500
#
# Epoch 012/025
# train_loss: 0.0118 - train_accuracy: 0.9958
# valid_loss: 0.1490 - valid_accuracy: 0.9500
#
# Epoch 013/025
# train_loss: 0.0099 - train_accuracy: 0.9958
# valid_loss: 0.1462 - valid_accuracy: 0.9667
#
# Epoch 014/025
# train_loss: 0.0093 - train_accuracy: 0.9958
# valid_loss: 0.1446 - valid_accuracy: 0.9667
#
# Epoch 015/025
# train_loss: 0.0077 - train_accuracy: 0.9958
# valid_loss: 0.1417 - valid_accuracy: 0.9667
#
# Epoch 016/025
# train_loss: 0.0060 - train_accuracy: 0.9958
# valid_loss: 0.1413 - valid_accuracy: 0.9667
#
# Epoch 017/025
# train_loss: 0.0065 - train_accuracy: 0.9958
# valid_loss: 0.1410 - valid_accuracy: 0.9667
#
# Epoch 018/025
# train_loss: 0.0057 - train_accuracy: 0.9958
# valid_loss: 0.1407 - valid_accuracy: 0.9667
#
# Epoch 019/025
# train_loss: 0.0056 - train_accuracy: 0.9958
# valid_loss: 0.1403 - valid_accuracy: 0.9667
#
# Epoch 020/025
# train_loss: 0.0056 - train_accuracy: 0.9958
# valid_loss: 0.1400 - valid_accuracy: 0.9667
#
# Epoch 021/025
# train_loss: 0.0054 - train_accuracy: 1.0000
# valid_loss: 0.1397 - valid_accuracy: 0.9667
#
# Epoch 022/025
# train_loss: 0.0051 - train_accuracy: 1.0000
# valid_loss: 0.1396 - valid_accuracy: 0.9667
#
# Epoch 023/025
# train_loss: 0.0047 - train_accuracy: 1.0000
# valid_loss: 0.1396 - valid_accuracy: 0.9667
#
# Epoch 024/025
# train_loss: 0.0051 - train_accuracy: 1.0000
# valid_loss: 0.1396 - valid_accuracy: 0.9667
#
# Complete! Validation Accuracy = 0.9833333333333333
#
#
#
#
# Fold-2 ...
#
# Number of train files: 240
# Number of valid_files: 60
#
# Device: cuda
#
# Model compiled
#
# Training ...
#
# Epoch 000/025
# train_loss: 0.7159 - train_accuracy: 0.7250
# valid_loss: 0.1690 - valid_accuracy: 0.9500
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f2.pt
#
# Epoch 001/025
# train_loss: 0.2260 - train_accuracy: 0.9167
# valid_loss: 0.1423 - valid_accuracy: 0.9500
#
# Epoch 002/025
# train_loss: 0.1494 - train_accuracy: 0.9542
# valid_loss: 0.1774 - valid_accuracy: 0.9333
#
# Epoch 003/025
# train_loss: 0.0985 - train_accuracy: 0.9583
# valid_loss: 0.2144 - valid_accuracy: 0.9667
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f2.pt
#
# Epoch 004/025
# train_loss: 0.1718 - train_accuracy: 0.9458
# valid_loss: 0.1571 - valid_accuracy: 0.9167
#
# Epoch 005/025
# train_loss: 0.0886 - train_accuracy: 0.9667
# valid_loss: 0.2826 - valid_accuracy: 0.9167
#
# Epoch 006/025
# train_loss: 0.0492 - train_accuracy: 0.9792
# valid_loss: 0.2732 - valid_accuracy: 0.9333
#
# Epoch 007/025
# train_loss: 0.0935 - train_accuracy: 0.9667
# valid_loss: 0.3706 - valid_accuracy: 0.9000
#
# Epoch 008/025
# train_loss: 0.0676 - train_accuracy: 0.9750
# valid_loss: 0.2066 - valid_accuracy: 0.9500
#
# Epoch 009/025
# train_loss: 0.0202 - train_accuracy: 0.9917
# valid_loss: 0.1856 - valid_accuracy: 0.9500
#
# Epoch 010/025
# train_loss: 0.0069 - train_accuracy: 1.0000
# valid_loss: 0.1927 - valid_accuracy: 0.9500
#
# Epoch 011/025
# train_loss: 0.0062 - train_accuracy: 1.0000
# valid_loss: 0.2026 - valid_accuracy: 0.9500
#
# Epoch 012/025
# train_loss: 0.0051 - train_accuracy: 1.0000
# valid_loss: 0.2121 - valid_accuracy: 0.9500
#
# Epoch 013/025
# train_loss: 0.0043 - train_accuracy: 1.0000
# valid_loss: 0.2233 - valid_accuracy: 0.9500
#
# Epoch 014/025
# train_loss: 0.0033 - train_accuracy: 1.0000
# valid_loss: 0.2329 - valid_accuracy: 0.9500
#
# Epoch 015/025
# train_loss: 0.0028 - train_accuracy: 1.0000
# valid_loss: 0.2405 - valid_accuracy: 0.9500
#
# Epoch 016/025
# train_loss: 0.0023 - train_accuracy: 1.0000
# valid_loss: 0.2417 - valid_accuracy: 0.9500
#
# Epoch 017/025
# train_loss: 0.0022 - train_accuracy: 1.0000
# valid_loss: 0.2427 - valid_accuracy: 0.9500
#
# Epoch 018/025
# train_loss: 0.0024 - train_accuracy: 1.0000
# valid_loss: 0.2437 - valid_accuracy: 0.9500
#
# Epoch 019/025
# train_loss: 0.0023 - train_accuracy: 1.0000
# valid_loss: 0.2449 - valid_accuracy: 0.9500
#
# Epoch 020/025
# train_loss: 0.0022 - train_accuracy: 1.0000
# valid_loss: 0.2463 - valid_accuracy: 0.9500
#
# Epoch 021/025
# train_loss: 0.0023 - train_accuracy: 1.0000
# valid_loss: 0.2477 - valid_accuracy: 0.9500
#
# Epoch 022/025
# train_loss: 0.0021 - train_accuracy: 1.0000
# valid_loss: 0.2478 - valid_accuracy: 0.9500
#
# Epoch 023/025
# train_loss: 0.0021 - train_accuracy: 1.0000
# valid_loss: 0.2480 - valid_accuracy: 0.9500
#
# Epoch 024/025
# train_loss: 0.0021 - train_accuracy: 1.0000
# valid_loss: 0.2482 - valid_accuracy: 0.9500
#
# Complete! Validation Accuracy = 0.9666666666666667
#
#
#
#
# Fold-3 ...
#
# Number of train files: 240
# Number of valid_files: 60
#
# Device: cuda
#
# Model compiled
#
# Training ...
#
# Epoch 000/025
# train_loss: 0.8046 - train_accuracy: 0.6917
# valid_loss: 0.2466 - valid_accuracy: 0.9167
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f3.pt
#
# Epoch 001/025
# train_loss: 0.2252 - train_accuracy: 0.8958
# valid_loss: 0.2337 - valid_accuracy: 0.8833
#
# Epoch 002/025
# train_loss: 0.2180 - train_accuracy: 0.9167
# valid_loss: 0.1076 - valid_accuracy: 0.9667
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f3.pt
#
# Epoch 003/025
# train_loss: 0.1323 - train_accuracy: 0.9625
# valid_loss: 0.0886 - valid_accuracy: 0.9833
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f3.pt
#
# Epoch 004/025
# train_loss: 0.1150 - train_accuracy: 0.9667
# valid_loss: 0.2628 - valid_accuracy: 0.9000
#
# Epoch 005/025
# train_loss: 0.1172 - train_accuracy: 0.9500
# valid_loss: 0.1117 - valid_accuracy: 0.9167
#
# Epoch 006/025
# train_loss: 0.0430 - train_accuracy: 0.9708
# valid_loss: 0.0856 - valid_accuracy: 0.9667
#
# Epoch 007/025
# train_loss: 0.0707 - train_accuracy: 0.9875
# valid_loss: 0.0705 - valid_accuracy: 0.9833
#
# Epoch 008/025
# train_loss: 0.0406 - train_accuracy: 0.9792
# valid_loss: 0.6413 - valid_accuracy: 0.8667
#
# Epoch 009/025
# train_loss: 0.0797 - train_accuracy: 0.9833
# valid_loss: 0.0426 - valid_accuracy: 0.9833
#
# Epoch 010/025
# train_loss: 0.0160 - train_accuracy: 0.9958
# valid_loss: 0.0277 - valid_accuracy: 0.9833
#
# Epoch 011/025
# train_loss: 0.0062 - train_accuracy: 1.0000
# valid_loss: 0.0323 - valid_accuracy: 0.9833
#
# Epoch 012/025
# train_loss: 0.0058 - train_accuracy: 1.0000
# valid_loss: 0.0244 - valid_accuracy: 0.9833
#
# Epoch 013/025
# train_loss: 0.0053 - train_accuracy: 1.0000
# valid_loss: 0.0251 - valid_accuracy: 0.9833
#
# Epoch 014/025
# train_loss: 0.0042 - train_accuracy: 1.0000
# valid_loss: 0.0298 - valid_accuracy: 0.9833
#
# Epoch 015/025
# train_loss: 0.0035 - train_accuracy: 1.0000
# valid_loss: 0.0229 - valid_accuracy: 0.9833
#
# Epoch 016/025
# train_loss: 0.0029 - train_accuracy: 1.0000
# valid_loss: 0.0233 - valid_accuracy: 0.9833
#
# Epoch 017/025
# train_loss: 0.0028 - train_accuracy: 1.0000
# valid_loss: 0.0236 - valid_accuracy: 0.9833
#
# Epoch 018/025
# train_loss: 0.0026 - train_accuracy: 1.0000
# valid_loss: 0.0240 - valid_accuracy: 0.9833
#
# Epoch 019/025
# train_loss: 0.0026 - train_accuracy: 1.0000
# valid_loss: 0.0241 - valid_accuracy: 0.9833
#
# Epoch 020/025
# train_loss: 0.0025 - train_accuracy: 1.0000
# valid_loss: 0.0239 - valid_accuracy: 0.9833
#
# Epoch 021/025
# train_loss: 0.0025 - train_accuracy: 1.0000
# valid_loss: 0.0240 - valid_accuracy: 0.9833
#
# Epoch 022/025
# train_loss: 0.0024 - train_accuracy: 1.0000
# valid_loss: 0.0241 - valid_accuracy: 0.9833
#
# Epoch 023/025
# train_loss: 0.0023 - train_accuracy: 1.0000
# valid_loss: 0.0239 - valid_accuracy: 0.9833
#
# Epoch 024/025
# train_loss: 0.0023 - train_accuracy: 1.0000
# valid_loss: 0.0240 - valid_accuracy: 0.9833
#
# Complete! Validation Accuracy = 0.9833333333333333
#
#
#
#
# Fold-4 ...
#
# Number of train files: 240
# Number of valid_files: 60
#
# Device: cuda
#
# Model compiled
#
# Training ...
#
# Epoch 000/025
# train_loss: 0.5470 - train_accuracy: 0.8083
# valid_loss: 0.4793 - valid_accuracy: 0.8500
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f4.pt
#
# Epoch 001/025
# train_loss: 0.2335 - train_accuracy: 0.8958
# valid_loss: 0.2999 - valid_accuracy: 0.9167
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f4.pt
#
# Epoch 002/025
# train_loss: 0.1736 - train_accuracy: 0.9292
# valid_loss: 0.1916 - valid_accuracy: 0.9667
# checkpoint saved: /mnt/scratch/crc/models/models_0512/model_f4.pt
#
# Epoch 003/025
# train_loss: 0.1856 - train_accuracy: 0.9500
# valid_loss: 0.4575 - valid_accuracy: 0.8833
#
# Epoch 004/025
# train_loss: 0.0770 - train_accuracy: 0.9750
# valid_loss: 0.4857 - valid_accuracy: 0.8833
#
# Epoch 005/025
# train_loss: 0.1124 - train_accuracy: 0.9542
# valid_loss: 1.0056 - valid_accuracy: 0.9000
#
# Epoch 006/025
# train_loss: 0.2124 - train_accuracy: 0.9625
# valid_loss: 0.2700 - valid_accuracy: 0.9667
#
# Epoch 007/025
# train_loss: 0.0297 - train_accuracy: 0.9917
# valid_loss: 0.3703 - valid_accuracy: 0.9333
#
# Epoch 008/025
# train_loss: 0.1322 - train_accuracy: 0.9542
# valid_loss: 0.2859 - valid_accuracy: 0.9500
#
# Epoch 009/025
# train_loss: 0.0211 - train_accuracy: 0.9958
# valid_loss: 0.2458 - valid_accuracy: 0.9500
#
# Epoch 010/025
# train_loss: 0.0064 - train_accuracy: 1.0000
# valid_loss: 0.2441 - valid_accuracy: 0.9500
#
# Epoch 011/025
# train_loss: 0.0101 - train_accuracy: 0.9958
# valid_loss: 0.2535 - valid_accuracy: 0.9333
#
# Epoch 012/025
# train_loss: 0.0075 - train_accuracy: 1.0000
# valid_loss: 0.2537 - valid_accuracy: 0.9500
#
# Epoch 013/025
# train_loss: 0.0048 - train_accuracy: 1.0000
# valid_loss: 0.2592 - valid_accuracy: 0.9500
#
# Epoch 014/025
# train_loss: 0.0044 - train_accuracy: 1.0000
# valid_loss: 0.2621 - valid_accuracy: 0.9500
#
# Epoch 015/025
# train_loss: 0.0032 - train_accuracy: 1.0000
# valid_loss: 0.2628 - valid_accuracy: 0.9500
#
# Epoch 016/025
# train_loss: 0.0034 - train_accuracy: 1.0000
# valid_loss: 0.2637 - valid_accuracy: 0.9500
#
# Epoch 017/025
# train_loss: 0.0031 - train_accuracy: 1.0000
# valid_loss: 0.2645 - valid_accuracy: 0.9500
#
# Epoch 018/025
# train_loss: 0.0031 - train_accuracy: 1.0000
# valid_loss: 0.2655 - valid_accuracy: 0.9500
#
# Epoch 019/025
# train_loss: 0.0033 - train_accuracy: 1.0000
# valid_loss: 0.2665 - valid_accuracy: 0.9500
#
# Epoch 020/025
# train_loss: 0.0031 - train_accuracy: 1.0000
# valid_loss: 0.2677 - valid_accuracy: 0.9500
#
# Epoch 021/025
# train_loss: 0.0029 - train_accuracy: 1.0000
# valid_loss: 0.2678 - valid_accuracy: 0.9500
#
# Epoch 022/025
# train_loss: 0.0028 - train_accuracy: 1.0000
# valid_loss: 0.2679 - valid_accuracy: 0.9500
#
# Epoch 023/025
# train_loss: 0.0031 - train_accuracy: 1.0000
# valid_loss: 0.2680 - valid_accuracy: 0.9500
#
# Epoch 024/025
# train_loss: 0.0034 - train_accuracy: 1.0000
# valid_loss: 0.2682 - valid_accuracy: 0.9500
#
# Complete! Validation Accuracy = 0.9666666666666667
